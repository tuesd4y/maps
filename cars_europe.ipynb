# %%
import geopandas as gpd
import shapely
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# read in country shapes
countries = gpd.read_file('cars/CNTR_RG_60M_2020_4326.geojson')
country_population = pd.read_csv('cars/API_SP.POP.TOTL_DS2_en_csv_v2_1637443.csv', header=2, index_col=1)
country_population.head()
# countries.head()
# Out:
#              Country Name     Indicator Name Indicator Code       1960  \
# Country Code
# ABW                 Aruba  Population, total    SP.POP.TOTL    54211.0
# AFG           Afghanistan  Population, total    SP.POP.TOTL  8996973.0
# AGO                Angola  Population, total    SP.POP.TOTL  5454933.0
# ALB               Albania  Population, total    SP.POP.TOTL  1608800.0
# AND               Andorra  Population, total    SP.POP.TOTL    13411.0
#
#                    1961       1962       1963       1964       1965  \
# Country Code
# ABW             55438.0    56225.0    56695.0    57032.0    57360.0
# AFG           9169410.0  9351441.0  9543205.0  9744781.0  9956320.0
# AGO           5531472.0  5608539.0  5679458.0  5735044.0  5770570.0
# ALB           1659800.0  1711319.0  1762621.0  1814135.0  1864791.0
# AND             14375.0    15370.0    16412.0    17469.0    18549.0
#
#                     1966  ...        2012        2013        2014        2015  \
# ...

# %%
# df_years = for year in range(0, 2020-1990)] = 
cars = pd.read_excel('cars/1990–2019_PC_by_country_EU+EFTA.xlsx', sheet_name=None, header = 2, index_col=0)

# cars['1990'].transpose()
for key in cars:
    cars[key] = cars[key] 
cars['1990']
# Out:
#                                                     1990-01-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         25877.0
# Belgium                                                         49036.0
# Denmark                                                          6648.0
# Finland                                                         17504.0
# France                                                         234571.0
# Germany                                                        226265.0
# Greece                                                          10437.0
# Ireland                                                         11149.0
# Italy                                                          310337.0
# Luxembourg                                                       2509.0
# Netherlands                                                     84370.0
# ...

# %%
box = shapely.geometry.LineString(coordinates = [[-25.312500,34.379713],[41.484375,71.272595]])

box = gpd.GeoSeries([box])
box = box.set_crs(epsg=4326)
box = box.envelope[0]

countries = countries[countries.intersects(box)]


data = []
# assign car numbers to countries
for y in range(0, 30):
    year = 1990 + y
    c = cars[f'%d' % year]
    pop = country_population[[f'%d' % year]]
    for month in range(0, 12):
        df = countries[['NAME_ENGL', 'geometry', 'ISO3_CODE']]
        c_month = c.iloc[:,month]
        
        def get_car_count(d):
            try: 
                return c_month[d['NAME_ENGL']]
            except: 
                return np.NaN
                
        df['cars'] = df.apply(get_car_count, axis = 1)
        df['carspp'] = df.dropna().apply(lambda r: r['cars'] / pop.iloc[:,0][r['ISO3_CODE']] * 1000, axis=1)
    
        data.append(df)
        
        
        
# cars['1990'].iloc[:,0]['Austria']
data[0].plot(column = 'cars')


pop = country_population[[f'%d' % year]]
pop
# Out:
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# ...

# %%
# plot
import geoplot as gplt
import matplotlib as mpl


cmap = sns.color_palette("Reds", as_cmap=True)
# cmap = sns.color_palette("YlOrBr", as_cmap=True)
# norm = mpl.colors.Normalize(vmin=0, vmax=14)
norm = mpl.colors.Normalize(vmin=0, vmax=210)


# norm = mpl.colors.LogNorm(vmin=1, vmax = 120)
cbar = plt.cm.ScalarMappable(norm=norm, cmap=cmap)

def plot(data: gpd.GeoDataFrame, i: int):
    year = 1990+i/12
    month = 1+i%12
    fig, ax = plt.subplots(1, 1, figsize=(16, 12))
    gplt.choropleth(data, hue = 'carspp', cmap = cmap, ax=ax, 
                     extent = (-13, 35, 30, 70), norm = norm,
                     legend = False, linewidth= .1)
    plt.suptitle(f'Car registrations per country, %02d/%04d' % (month, year), fontsize=16)
    plt.subplots_adjust(top=0.94)
    plt.colorbar(cbar, ax = ax, fraction = .04, orientation = 'horizontal', pad = .05, 
                 label = 'new registrations per 1000 persons')
    fig.savefig(f"frames/frame_%04d.png" % i, 
                dpi=100, bbox_inches='tight')
    plt.close()
    
# for i in range(0, (2019-1990+1)*12):
#     plot(data[i], i)
# np.max([d['carspp'].max() for d in data])
# plot(data[11], 1990, 11)

def plot_avg(i: int):
    year = i + 1990
    
    # sum up values for the whole year into d
    d= data[i*12]
    for m in range(1,12):
        d['carspp'] = d['carspp'].add(data[i*12+m]['carspp'], fill_value=0)
        
    fig, ax = plt.subplots(1, 1, figsize=(32, 24))
    gplt.choropleth(d, hue = 'carspp', cmap = cmap, ax=ax, 
                     extent = (-13, 35, 30, 70), norm = norm,
                     legend = False, linewidth= .05)
    plt.suptitle(f'Car registrations per country, {year}', fontsize=36)
    plt.subplots_adjust(top=0.94)
    plt.colorbar(cbar, ax = ax, fraction = .04, orientation = 'horizontal', pad = .05) \
            .set_label(label='new registrations per 1000 persons', size=15)
    fig.savefig(f"frames/frame_%02d.png" % i, 
                dpi=100, bbox_inches='tight')
    plt.close()
    print('', d['carspp'].min(),  d['carspp'].max())


        
        
cmap = sns.color_palette("Reds", as_cmap=True)
norm = mpl.colors.Normalize(vmin=0, vmax=120)
cbar = plt.cm.ScalarMappable(norm=norm, cmap=cmap)

for i in range(0, 2019-1990+1):
    plot_avg(i)

# data[0].head()
# Out:
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#  11.325130492021414 100.62066256383399
#  12.730504874543964 111.27906976744184
#  13.595221888491691 94.97800726716392
#  11.02074096501947 74.65626768979182
#  10.419938433862631 72.17720419432898
#  11.836885907636445 68.59345365555215
#  13.179718724078125 72.3761240871507
#  14.995133313992278 74.90284896888782
#  16.8037730298067 84.59618554273604
#  22.698335893147178 94.02636622335791
#  21.104513882646238 96.02567041026816
#  17.94679874143066 97.01149425287356
#  19.54999813801147 97.27797388916906
#  2.2086470155741385 96.58348648229746
# ...

# %%
# !ffmpeg -framerate 6 -i frames/frame_%2d.png -c:v h264 -r 30 frames/vid2.mp4 -y
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 12.0.0 (clang-1200.0.32.27)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1_4 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
data[0]
# Out:
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# ...

# %%
country_population['1990']['AUT']
# Out:
# 7677850.0

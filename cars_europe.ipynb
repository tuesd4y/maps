# %%
import geopandas as gpd
import shapely
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# read in country shapes
countries = gpd.read_file('cars/CNTR_RG_60M_2020_4326.geojson')
country_population = pd.read_csv('cars/API_SP.POP.TOTL_DS2_en_csv_v2_1637443.csv', header=2, index_col=1)
country_population.head()
# countries.head()
# Out:
#              Country Name     Indicator Name Indicator Code       1960  \
# Country Code
# ABW                 Aruba  Population, total    SP.POP.TOTL    54211.0
# AFG           Afghanistan  Population, total    SP.POP.TOTL  8996973.0
# AGO                Angola  Population, total    SP.POP.TOTL  5454933.0
# ALB               Albania  Population, total    SP.POP.TOTL  1608800.0
# AND               Andorra  Population, total    SP.POP.TOTL    13411.0
#
#                    1961       1962       1963       1964       1965  \
# Country Code
# ABW             55438.0    56225.0    56695.0    57032.0    57360.0
# AFG           9169410.0  9351441.0  9543205.0  9744781.0  9956320.0
# AGO           5531472.0  5608539.0  5679458.0  5735044.0  5770570.0
# ALB           1659800.0  1711319.0  1762621.0  1814135.0  1864791.0
# AND             14375.0    15370.0    16412.0    17469.0    18549.0
#
#                     1966  ...        2012        2013        2014        2015  \
# Country Code              ...
# ABW              57715.0  ...    102560.0    103159.0    103774.0    104341.0
# AFG           10174836.0  ...  31161376.0  32269589.0  33370794.0  34413603.0
# AGO            5781214.0  ...  25107931.0  26015780.0  26941779.0  27884381.0
# ALB            1914573.0  ...   2900401.0   2895092.0   2889104.0   2880703.0
# AND              19647.0  ...     82427.0     80774.0     79213.0     78011.0
#
#                     2016        2017        2018        2019  2020  \
# Country Code
# ABW             104872.0    105366.0    105845.0    106314.0   NaN
# AFG           35383128.0  36296400.0  37172386.0  38041754.0   NaN
# AGO           28842484.0  29816748.0  30809762.0  31825295.0   NaN
# ALB            2876101.0   2873457.0   2866376.0   2854191.0   NaN
# AND              77297.0     77001.0     77006.0     77142.0   NaN
#
#               Unnamed: 65
# Country Code
# ABW                   NaN
# AFG                   NaN
# AGO                   NaN
# ALB                   NaN
# AND                   NaN
#
# [5 rows x 65 columns]

# %%
# df_years = for year in range(0, 2020-1990)] = 
cars = pd.read_excel('cars/1990–2019_PC_by_country_EU+EFTA.xlsx', sheet_name=None, header = 2, index_col=0)

# cars['1990'].transpose()
for key in cars:
    cars[key] = cars[key] 
cars['1990']
# Out:
#                                                     1990-01-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         25877.0
# Belgium                                                         49036.0
# Denmark                                                          6648.0
# Finland                                                         17504.0
# France                                                         234571.0
# Germany                                                        226265.0
# Greece                                                          10437.0
# Ireland                                                         11149.0
# Italy                                                          310337.0
# Luxembourg                                                       2509.0
# Netherlands                                                     84370.0
# Portugal                                                        15258.0
# Spain                                                           84556.0
# Sweden                                                          21379.0
# United Kingdom                                                 206393.0
# EU-151                                                        1306289.0
# Norway                                                           5335.0
# Switzerland                                                     27768.0
# EFTA                                                            33103.0
# EU15 + EFTA                                                   1339392.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-02-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         20780.0
# Belgium                                                         47698.0
# Denmark                                                          6925.0
# Finland                                                          9740.0
# France                                                         191225.0
# Germany                                                        234428.0
# Greece                                                           6809.0
# Ireland                                                          8328.0
# Italy                                                          219117.0
# Luxembourg                                                       3805.0
# Netherlands                                                     35007.0
# Portugal                                                        15211.0
# Spain                                                           84008.0
# Sweden                                                          20879.0
# United Kingdom                                                 167420.0
# EU-151                                                        1071380.0
# Norway                                                           4909.0
# Switzerland                                                     29493.0
# EFTA                                                            34402.0
# EU15 + EFTA                                                   1105782.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-03-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         32661.0
# Belgium                                                         51375.0
# Denmark                                                          9808.0
# Finland                                                         16816.0
# France                                                         222418.0
# Germany                                                        325963.0
# Greece                                                           4672.0
# Ireland                                                          8494.0
# Italy                                                          225059.0
# Luxembourg                                                       4537.0
# Netherlands                                                     58695.0
# Portugal                                                        18873.0
# Spain                                                          104633.0
# Sweden                                                          25452.0
# United Kingdom                                                 208733.0
# EU-151                                                        1318189.0
# Norway                                                           5598.0
# Switzerland                                                     38580.0
# EFTA                                                            44178.0
# EU15 + EFTA                                                   1362367.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-04-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         31991.0
# Belgium                                                         46637.0
# Denmark                                                          8515.0
# Finland                                                         15769.0
# France                                                         191541.0
# Germany                                                        290071.0
# Greece                                                          13344.0
# Ireland                                                          9331.0
# Italy                                                          214460.0
# Luxembourg                                                       4043.0
# Netherlands                                                     47200.0
# Portugal                                                        17991.0
# Spain                                                           88956.0
# Sweden                                                          22028.0
# United Kingdom                                                 166913.0
# EU-151                                                        1168790.0
# Norway                                                           4950.0
# Switzerland                                                     33395.0
# EFTA                                                            38345.0
# EU15 + EFTA                                                   1207135.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-05-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         29744.0
# Belgium                                                         40780.0
# Denmark                                                          7980.0
# Finland                                                         12239.0
# France                                                         196828.0
# Germany                                                        299364.0
# Greece                                                          12536.0
# Ireland                                                         10046.0
# Italy                                                          232627.0
# Luxembourg                                                       3852.0
# Netherlands                                                     47134.0
# Portugal                                                        19080.0
# Spain                                                           94306.0
# Sweden                                                          23491.0
# United Kingdom                                                 173896.0
# EU-151                                                        1203903.0
# Norway                                                           6074.0
# Switzerland                                                     29203.0
# EFTA                                                            35277.0
# EU15 + EFTA                                                   1239180.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-06-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         25876.0
# Belgium                                                         43018.0
# Denmark                                                          7893.0
# Finland                                                         14874.0
# France                                                         151378.0
# Germany                                                        272254.0
# Greece                                                           9790.0
# Ireland                                                          7922.0
# Italy                                                          201085.0
# Luxembourg                                                       3390.0
# Netherlands                                                     48831.0
# Portugal                                                        19034.0
# Spain                                                           92311.0
# Sweden                                                          23321.0
# United Kingdom                                                 142697.0
# EU-151                                                        1063674.0
# Norway                                                           5881.0
# Switzerland                                                     36682.0
# EFTA                                                            42563.0
# EU15 + EFTA                                                   1106237.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-07-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         25884.0
# Belgium                                                         32674.0
# Denmark                                                          5853.0
# Finland                                                         10673.0
# France                                                         228317.0
# Germany                                                        295892.0
# Greece                                                          11624.0
# Ireland                                                          7714.0
# Italy                                                          206843.0
# Luxembourg                                                       3147.0
# Netherlands                                                     33566.0
# Portugal                                                        19211.0
# Spain                                                          106009.0
# Sweden                                                          12779.0
# United Kingdom                                                  45707.0
# EU-151                                                        1045893.0
# Norway                                                           5002.0
# Switzerland                                                     21332.0
# EFTA                                                            26334.0
# EU15 + EFTA                                                   1072227.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-08-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         21055.0
# Belgium                                                         26509.0
# Denmark                                                          6239.0
# Finland                                                          9667.0
# France                                                         178136.0
# Germany                                                        251007.0
# Greece                                                          10257.0
# Ireland                                                          6080.0
# Italy                                                          107075.0
# Luxembourg                                                       2287.0
# Netherlands                                                     33974.0
# Portugal                                                        15250.0
# Spain                                                           73744.0
# Sweden                                                          13837.0
# United Kingdom                                                 432867.0
# EU-151                                                        1187984.0
# Norway                                                           4845.0
# Switzerland                                                     20589.0
# EFTA                                                            25434.0
# EU15 + EFTA                                                   1213418.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-09-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         21013.0
# Belgium                                                         40974.0
# Denmark                                                          6897.0
# Finland                                                          9621.0
# France                                                         138220.0
# Germany                                                        237534.0
# Greece                                                           6052.0
# Ireland                                                          4773.0
# Italy                                                          153386.0
# Luxembourg                                                       2120.0
# Netherlands                                                     33948.0
# Portugal                                                        14075.0
# Spain                                                           50630.0
# Sweden                                                          16201.0
# United Kingdom                                                 153595.0
# EU-151                                                         889039.0
# Norway                                                           4951.0
# Switzerland                                                     24780.0
# EFTA                                                            29731.0
# EU15 + EFTA                                                    918770.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-10-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         23368.0
# Belgium                                                         34705.0
# Denmark                                                          6182.0
# Finland                                                         10307.0
# France                                                         221772.0
# Germany                                                        335700.0
# Greece                                                          10700.0
# Ireland                                                          4278.0
# Italy                                                          183925.0
# Luxembourg                                                       3608.0
# Netherlands                                                     39386.0
# Portugal                                                        17373.0
# Spain                                                           75103.0
# Sweden                                                          19898.0
# United Kingdom                                                 130377.0
# EU-151                                                        1116682.0
# Norway                                                           5887.0
# Switzerland                                                     28318.0
# EFTA                                                            34205.0
# EU15 + EFTA                                                   1150887.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-11-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         19233.0
# Belgium                                                         34890.0
# Denmark                                                          4642.0
# Finland                                                          7661.0
# France                                                         193530.0
# Germany                                                        347185.0
# Greece                                                           9772.0
# Ireland                                                          2760.0
# Italy                                                          157300.0
# Luxembourg                                                       3024.0
# Netherlands                                                     31294.0
# Portugal                                                        17337.0
# Spain                                                           69007.0
# Sweden                                                          16491.0
# United Kingdom                                                 117499.0
# EU-151                                                        1031625.0
# Norway                                                           5248.0
# Switzerland                                                     18707.0
# EFTA                                                            23955.0
# EU15 + EFTA                                                   1055580.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                     1990-12-01 00:00:00  \
# Country
# PC-Passenger Car                                                    NaN
# Austria                                                         11136.0
# Belgium                                                         25210.0
# Denmark                                                          3072.0
# Finland                                                          4224.0
# France                                                         161194.0
# Germany                                                        234125.0
# Greece                                                           9487.0
# Ireland                                                          1709.0
# Italy                                                           95841.0
# Luxembourg                                                       2100.0
# Netherlands                                                      9222.0
# Portugal                                                        22231.0
# Spain                                                           64907.0
# Sweden                                                          14185.0
# United Kingdom                                                  62837.0
# EU-151                                                         721480.0
# Norway                                                           3221.0
# Switzerland                                                     21052.0
# EFTA                                                            24273.0
# EU15 + EFTA                                                    745753.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...                  NaN
# 1The 15 Member States of the European Union fro...                  NaN
#
#                                                             FY
# Country
# PC-Passenger Car                                           NaN
# Austria                                               288618.0
# Belgium                                               473506.0
# Denmark                                                80654.0
# Finland                                               139095.0
# France                                               2309130.0
# Germany                                              3349788.0
# Greece                                                115480.0
# Ireland                                                82584.0
# Italy                                                2307055.0
# Luxembourg                                             38422.0
# Netherlands                                           502627.0
# Portugal                                              210924.0
# Spain                                                 988170.0
# Sweden                                                229941.0
# United Kingdom                                       2008934.0
# EU-151                                              13124928.0
# Norway                                                 61901.0
# Switzerland                                           329899.0
# EFTA                                                  391800.0
# EU15 + EFTA                                         13516728.0
# SOURCE: ASSOCIATION AUXILIAIRE DE L'AUTOMOBILE ...         NaN
# 1The 15 Member States of the European Union fro...         NaN

# %%
box = shapely.geometry.LineString(coordinates = [[-25.312500,34.379713],[41.484375,71.272595]])

box = gpd.GeoSeries([box])
box = box.set_crs(epsg=4326)
box = box.envelope[0]

countries = countries[countries.intersects(box)]


data = []
# assign car numbers to countries
for y in range(0, 30):
    year = 1990 + y
    c = cars[f'%d' % year]
    pop = country_population[[f'%d' % year]]
    for month in range(0, 12):
        df = countries[['NAME_ENGL', 'geometry', 'ISO3_CODE']]
        c_month = c.iloc[:,month]
        
        def get_car_count(d):
            try: 
                return c_month[d['NAME_ENGL']]
            except: 
                return np.NaN
                
        df['cars'] = df.apply(get_car_count, axis = 1)
        df['carspp'] = df.dropna().apply(lambda r: r['cars'] / pop.iloc[:,0][r['ISO3_CODE']] * 1000, axis=1)
    
        data.append(df)
        
        
        
# cars['1990'].iloc[:,0]['Austria']
data[0].plot(column = 'cars')


pop = country_population[[f'%d' % year]]
pop
# Out:
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/dev/anaconda3/envs/maps/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#                     2019
# Country Code
# ABW             106314.0
# AFG           38041754.0
# AGO           31825295.0
# ALB            2854191.0
# AND              77142.0
# ...                  ...
# XKX            1794248.0
# YEM           29161922.0
# ZAF           58558270.0
# ZMB           17861030.0
# ZWE           14645468.0
#
# [264 rows x 1 columns]

# %%
# plot
import geoplot as gplt
import matplotlib as mpl


cmap = sns.color_palette("Reds", as_cmap=True)
# cmap = sns.color_palette("YlOrBr", as_cmap=True)
norm = mpl.colors.Normalize(vmin=0, vmax=14)
# norm = mpl.colors.LogNorm(vmin=1, vmax = 120)
cbar = plt.cm.ScalarMappable(norm=norm, cmap=cmap)

def plot(data: gpd.GeoDataFrame, i: int):
    year = 1990+i/12
    month = 1+i%12
    fig, ax = plt.subplots(1, 1, figsize=(16, 12))
    gplt.choropleth(data, hue = 'carspp', cmap = cmap, ax=ax, 
                     extent = (-13, 35, 30, 70), norm = norm,
                     legend = False, linewidth= .1)
    plt.suptitle(f'Car registrations per country, %02d/%04d' % (month, year), fontsize=16)
    plt.subplots_adjust(top=0.94)
    plt.colorbar(cbar, ax = ax, fraction = .04, orientation = 'horizontal', pad = .05, 
                 label = 'new registrations per 1000 persons')
    fig.savefig(f"frames/frame_%04d.png" % i, 
                dpi=100, bbox_inches='tight')
    plt.close()
    
# for i in range(0, (2019-1990+1)*12):
#     plot(data[i], i)
# np.max([d['carspp'].max() for d in data])
# plot(data[11], 1990, 11)

for i in range(0, 2019-1990+1):
# Out:
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   49036.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   25877.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   27768.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  310337.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  226265.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    6648.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC   10437.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   84556.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN   17504.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  234571.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL   11149.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   21379.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    2509.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   84370.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    5335.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   15258.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  206393.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#        carspp
# 1         NaN
# 13        NaN
# 16   4.919648
# 18        NaN
# 34        NaN
# 39        NaN
# 44   3.370345
# 52        NaN
# 58   4.134900
# 62   5.471459
# 63        NaN
# 76        NaN
# 77        NaN
# 78   2.848500
# 80   1.293149
# 83        NaN
# 85        NaN
# 88   1.023557
# 90   2.175504
# 92   3.510326
# 96        NaN
# 97   4.027959
# 100       NaN
# 101       NaN
# 103       NaN
# 104       NaN
# 116       NaN
# 118       NaN
# 119  3.172761
# 121       NaN
# 124       NaN
# 125       NaN
# 129  2.497887
# 132       NaN
# 138       NaN
# 140       NaN
# 144       NaN
# 145  6.570643
# 146       NaN
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  5.642908
# 198  1.257818
# 202       NaN
# 203       NaN
# 206       NaN
# 211  1.528365
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  3.605270
# 239       NaN   0
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   47698.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   20780.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   29493.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  219117.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  234428.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    6925.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC    6809.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   84008.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN    9740.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  191225.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL    8328.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   20879.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    3805.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   35007.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    4909.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   15211.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  167420.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#        carspp
# 1         NaN
# 13        NaN
# 16   4.785410
# 18        NaN
# 34        NaN
# 39        NaN
# 44   2.706487
# 52        NaN
# 58   4.391768
# 62   3.863186
# 63        NaN
# 76        NaN
# 77        NaN
# 78   2.951266
# 80   1.347030
# 83        NaN
# 85        NaN
# 88   0.667759
# 90   2.161404
# 92   1.953301
# 96        NaN
# 97   3.283639
# 100       NaN
# 101       NaN
# 103       NaN
# 104       NaN
# 116       NaN
# 118       NaN
# 119  2.369966
# 121       NaN
# 124       NaN
# 125       NaN
# 129  2.439468
# 132       NaN
# 138       NaN
# 140       NaN
# 144       NaN
# 145  9.964646
# 146       NaN
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  2.341369
# 198  1.157381
# 202       NaN
# 203       NaN
# 206       NaN
# 211  1.523657
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  2.924490
# 239       NaN   1
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   51375.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   32661.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   38580.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  225059.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  325963.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    9808.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC    4672.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP  104633.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN   16816.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  222418.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL    8494.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   25452.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    4537.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   58695.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    5598.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   18873.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  208733.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#         carspp
# 1          NaN
# 13         NaN
# 16    5.154314
# 18         NaN
# 34         NaN
# 39         NaN
# 44    4.253925
# 52         NaN
# 58    5.744902
# 62    3.967948
# 63         NaN
# 76         NaN
# 77         NaN
# 78    4.103620
# 80    1.907823
# 83         NaN
# 85         NaN
# 88    0.458183
# 90    2.692056
# 92    3.372352
# 96         NaN
# 97    3.819273
# 100        NaN
# 101        NaN
# 103        NaN
# 104        NaN
# 116        NaN
# 118        NaN
# 119   2.417206
# 121        NaN
# 124        NaN
# 125        NaN
# 129   2.973769
# 132        NaN
# 138        NaN
# 140        NaN
# 144        NaN
# 145  11.881629
# 146        NaN
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 153        NaN
# 161        NaN
# 172        NaN
# 176        NaN
# 184        NaN
# 197   3.925690
# 198   1.319825
# 202        NaN
# 203        NaN
# 206        NaN
# 211   1.890473
# 215        NaN
# 216        NaN
# 218        NaN
# 222        NaN
# 224   3.646145
# 239        NaN   2
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   46637.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   31991.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   33395.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  214460.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  290071.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    8515.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC   13344.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   88956.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN   15769.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  191541.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL    9331.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   22028.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    4043.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   47200.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    4950.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   17991.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  166913.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#         carspp
# 1          NaN
# 13         NaN
# 16    4.678963
# 18         NaN
# 34         NaN
# 39         NaN
# 44    4.166661
# 52         NaN
# 58    4.972810
# 62    3.781080
# 63         NaN
# 76         NaN
# 77         NaN
# 78    3.651768
# 80    1.656312
# 83         NaN
# 85         NaN
# 88    1.308647
# 90    2.288709
# 92    3.162382
# 96         NaN
# 97    3.289065
# 100        NaN
# 101        NaN
# 103        NaN
# 104        NaN
# 116        NaN
# 118        NaN
# 119   2.655398
# 121        NaN
# 124        NaN
# 125        NaN
# 129   2.573715
# 132        NaN
# 138        NaN
# 140        NaN
# 144        NaN
# 145  10.587927
# 146        NaN
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 153        NaN
# 161        NaN
# 172        NaN
# 176        NaN
# 184        NaN
# 197   3.156872
# 198   1.167047
# 202        NaN
# 203        NaN
# 206        NaN
# 211   1.802124
# 215        NaN
# 216        NaN
# 218        NaN
# 222        NaN
# 224   2.915634
# 239        NaN   3
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   40780.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   29744.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   29203.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  232627.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  299364.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    7980.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC   12536.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   94306.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN   12239.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  196828.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL   10046.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   23491.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    3852.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   47134.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    6074.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   19080.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  173896.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#         carspp
# 1          NaN
# 13         NaN
# 16    4.091346
# 18         NaN
# 34         NaN
# 39         NaN
# 44    3.874001
# 52         NaN
# 58    4.348584
# 62    4.101377
# 63         NaN
# 76         NaN
# 77         NaN
# 78    3.768760
# 80    1.552246
# 83         NaN
# 85         NaN
# 88    1.229406
# 90    2.426357
# 92    2.454461
# 96         NaN
# 97    3.379851
# 100        NaN
# 101        NaN
# 103        NaN
# 104        NaN
# 116        NaN
# 118        NaN
# 119   2.858871
# 121        NaN
# 124        NaN
# 125        NaN
# 129   2.744649
# 132        NaN
# 138        NaN
# 140        NaN
# 144        NaN
# 145  10.087731
# 146        NaN
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 153        NaN
# 161        NaN
# 172        NaN
# 176        NaN
# 184        NaN
# 197   3.152458
# 198   1.432050
# 202        NaN
# 203        NaN
# 206        NaN
# 211   1.911207
# 215        NaN
# 216        NaN
# 218        NaN
# 222        NaN
# 224   3.037613
# 239        NaN   4
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   43018.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR       NaN
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   25876.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL       NaN
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   36682.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  201085.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  272254.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK    7893.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST       NaN
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC    9790.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   92311.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN   14874.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  151378.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV       NaN
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN       NaN
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL    7922.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   23321.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN       NaN
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU       NaN
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    3390.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA       NaN
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   48831.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR    5881.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK       NaN
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL       NaN
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   19034.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  142697.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#        carspp
# 1         NaN
# 13        NaN
# 16   4.315879
# 18        NaN
# 34        NaN
# 39        NaN
# 44   3.370214
# 52        NaN
# 58   5.462273
# 62   3.545270
# 63        NaN
# 76        NaN
# 77        NaN
# 78   3.427466
# 80   1.535323
# 83        NaN
# 85        NaN
# 88   0.960106
# 90   2.375029
# 92   2.982895
# 96        NaN
# 97   2.599402
# 100       NaN
# 101       NaN
# 103       NaN
# 104       NaN
# 116       NaN
# 118       NaN
# 119  2.254428
# 121       NaN
# 124       NaN
# 125       NaN
# 129  2.724787
# 132       NaN
# 138       NaN
# 140       NaN
# 144       NaN
# 145  8.877832
# 146       NaN
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  3.265958
# 198  1.386547
# 202       NaN
# 203       NaN
# 206       NaN
# 211  1.906600
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  2.492629
# 239       NaN   5
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# ...
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  1.948785
# 198  1.959462
# 202       NaN
# 203  1.730083
# 206  1.233498
# 211  1.523845
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  2.143372
# 239       NaN   357
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   34574.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR    3097.0
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   23271.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL     641.0
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   24226.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  150819.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  299127.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK   18115.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST    2051.0
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC    7464.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP   93155.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN    8684.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  172731.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV    3475.0
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN   14214.0
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL     769.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   30502.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN    4426.0
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU    4333.0
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    3950.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA    1294.0
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   39149.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR   10031.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK    8000.0
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL   45128.0
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   16400.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  156621.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#        carspp
# 1         NaN
# 13        NaN
# 16   3.010609
# 18   0.443966
# 34        NaN
# 39        NaN
# 44   2.621474
# 52   1.774085
# 58   2.825245
# 62   2.501252
# 63        NaN
# 76        NaN
# 77        NaN
# 78   3.598183
# 80   3.113317
# 83        NaN
# 85   1.546069
# 88   0.696508
# 90   1.978789
# 92   1.573099
# 96        NaN
# 97   2.575772
# 100       NaN
# 101       NaN
# 103       NaN
# 104       NaN
# 116  0.854333
# 118  1.454869
# 119  0.155623
# 121       NaN
# 124       NaN
# 125       NaN
# 129  2.965548
# 132  2.119787
# 138       NaN
# 140       NaN
# 144  1.554805
# 145  6.372037
# 146  0.676499
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  2.258659
# 198  1.875691
# 202       NaN
# 203  1.466794
# 206  1.188490
# 211  1.596975
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  2.343419
# 239       NaN   358
#                   NAME_ENGL  \
# 1                   Belarus
# 13   Bosnia and Herzegovina
# 16                  Belgium
# 18                 Bulgaria
# 34                  Andorra
# 39                  Albania
# 44                  Austria
# 52                  Iceland
# 58              Switzerland
# 62                    Italy
# 63                   Jersey
# 76                   Cyprus
# 77                  Czechia
# 78                  Germany
# 80                  Denmark
# 83                  Algeria
# 85                  Estonia
# 88                   Greece
# 90                    Spain
# 92                  Finland
# 96                   Faroes
# 97                   France
# 100                 Georgia
# 101                Guernsey
# 103               Gibraltar
# 104               Greenland
# 116                 Croatia
# 118                 Hungary
# 119                 Ireland
# 121             Isle of Man
# 124                    Iraq
# 125      Russian Federation
# 129                  Sweden
# 132                Slovenia
# 138                 Lebanon
# 140           Liechtenstein
# 144               Lithuania
# 145              Luxembourg
# 146                  Latvia
# 148                 Morocco
# 149                  Monaco
# 150                 Moldova
# 151              Montenegro
# 153              San Marino
# 161                   Syria
# 172                 Tunisia
# 176         North Macedonia
# 184                   Malta
# 197             Netherlands
# 198                  Norway
# 202  Svalbard and Jan Mayen
# 203                Slovakia
# 206                  Poland
# 211                Portugal
# 215                 Romania
# 216                  Serbia
# 218                  Turkey
# 222                 Ukraine
# 224          United Kingdom
# 239            Vatican City
#
#                                               geometry ISO3_CODE      cars  \
# 1    POLYGON ((31.78700 52.11100, 30.91100 52.02500...       BLR       NaN
# 13   POLYGON ((19.02200 44.85500, 19.35100 44.88900...       BIH       NaN
# 16   POLYGON ((6.02100 50.75400, 6.31600 50.49700, ...       BEL   32800.0
# 18   POLYGON ((28.57900 43.73900, 28.49800 43.43400...       BGR    3109.0
# 34   POLYGON ((1.72600 42.50400, 1.49600 42.47400, ...       AND       NaN
# 39   POLYGON ((20.07600 42.55600, 20.26500 42.39300...       ALB       NaN
# 44   POLYGON ((16.94000 48.61700, 16.95000 48.53600...       AUT   22728.0
# 52   POLYGON ((-13.97900 65.57700, -13.75800 65.241...       ISL     587.0
# 58   POLYGON ((9.55900 47.54200, 9.53100 47.27100, ...       CHE   34508.0
# 62   MULTIPOLYGON (((13.71400 46.52300, 13.68400 46...       ITA  140075.0
# 63   POLYGON ((-2.36400 49.28800, -2.01400 49.27800...       JEY       NaN
# 76   POLYGON ((33.62500 34.85100, 32.94200 34.64200...       CYP       NaN
# 77   POLYGON ((14.82300 50.87100, 15.18200 50.95700...       CZE       NaN
# 78   MULTIPOLYGON (((9.42200 54.83200, 9.46900 54.8...       DEU  283380.0
# 80   MULTIPOLYGON (((9.42200 54.83200, 9.27400 54.8...       DNK   15495.0
# 83   POLYGON ((8.64200 36.94100, 8.34400 36.52800, ...       DZA       NaN
# 85   MULTIPOLYGON (((27.35200 57.51800, 26.45500 57...       EST    1918.0
# 88   MULTIPOLYGON (((26.03300 40.73000, 25.63200 40...       GRC    6668.0
# 90   MULTIPOLYGON (((-1.78600 43.35000, -1.76900 43...       ESP  105853.0
# 92   MULTIPOLYGON (((28.89700 69.04300, 28.47800 68...       FIN    8212.0
# 96   POLYGON ((-7.16100 62.12700, -7.13300 62.28400...       FRO       NaN
# 97   MULTIPOLYGON (((5.81800 49.54600, 5.89300 49.4...       FRA  211194.0
# 100  POLYGON ((46.42100 41.90400, 46.28300 41.73300...       GEO       NaN
# 101  POLYGON ((-2.72000 49.44400, -2.47000 49.64200...       GGY       NaN
# 103  POLYGON ((-5.33900 36.15200, -5.34100 36.12500...       GIB       NaN
# 104  MULTIPOLYGON (((-24.53000 82.93200, -24.40900 ...       GRL       NaN
# 116  MULTIPOLYGON (((18.89000 45.92100, 19.03400 45...       HRV    4064.0
# 118  POLYGON ((22.15500 48.40300, 22.89600 47.95400...       HUN   16139.0
# 119  POLYGON ((-6.26800 54.10200, -6.21500 53.63300...       IRL     224.0
# 121  POLYGON ((-4.77000 54.06600, -4.72100 54.20300...       IMN       NaN
# 124  POLYGON ((44.79300 37.17600, 45.13800 36.46900...       IRQ       NaN
# 125  MULTIPOLYGON (((130.67500 42.28400, 130.62400 ...       RUS       NaN
# 129  MULTIPOLYGON (((20.54900 69.06000, 23.40800 68...       SWE   48129.0
# 132  POLYGON ((16.59700 46.47600, 16.24200 46.49000...       SVN    3173.0
# 138  POLYGON ((35.62400 33.24200, 35.10300 33.09400...       LBN       NaN
# 140  POLYGON ((9.60700 47.06100, 9.47600 47.05200, ...       LIE       NaN
# 144  POLYGON ((26.63000 55.68100, 26.74000 55.26400...       LTU    3277.0
# 145  POLYGON ((6.13800 50.13000, 6.47500 49.82100, ...       LUX    3794.0
# 146  POLYGON ((28.15500 56.17000, 27.63100 55.87400...       LVA    1263.0
# 148  POLYGON ((-5.34300 35.87100, -5.32800 35.71700...       MAR       NaN
# 149  POLYGON ((7.43900 43.74900, 7.43800 43.74700, ...       MCO       NaN
# 150  POLYGON ((28.21100 45.46700, 28.11600 46.10800...       MDA       NaN
# 151  POLYGON ((20.07600 42.55600, 19.83100 42.46600...       MNE       NaN
# 153  POLYGON ((12.45300 43.89400, 12.45000 43.89700...       SMR       NaN
# 161  POLYGON ((42.35600 37.10800, 41.33100 36.38400...       SYR       NaN
# 172  POLYGON ((11.56400 33.16500, 11.53900 32.53300...       TUN       NaN
# 176  POLYGON ((22.92800 41.33900, 22.87900 41.34100...       MKD       NaN
# 184  MULTIPOLYGON (((14.64600 35.93300, 14.43300 35...       MLT       NaN
# 197  MULTIPOLYGON (((6.02100 50.75400, 5.81900 50.7...       NLD   42436.0
# 198  MULTIPOLYGON (((30.86500 69.76000, 30.93000 69...       NOR   11254.0
# 202  MULTIPOLYGON (((17.88100 79.75100, 17.83700 79...       SJM       NaN
# 203  POLYGON ((22.56700 49.08800, 22.38300 48.86200...       SVK    7680.0
# 206  POLYGON ((19.80400 54.44200, 20.13600 54.41600...       POL   52503.0
# 211  MULTIPOLYGON (((-7.40200 37.17500, -8.07400 37...       PRT   17726.0
# 215  POLYGON ((28.21100 45.46700, 28.65200 45.25100...       ROU       NaN
# 216  POLYGON ((22.67500 44.21600, 22.53600 44.04600...       SRB       NaN
# 218  MULTIPOLYGON (((41.54700 41.52000, 42.51500 41...       TUR       NaN
# 222  POLYGON ((38.23100 47.11900, 34.45900 46.15400...       UKR       NaN
# 224  MULTIPOLYGON (((-0.11000 51.51000, -0.02500 51...       GBR  148997.0
# 239  POLYGON ((12.36200 41.88400, 12.43300 41.94000...       VAT       NaN
#
#        carspp
# 1         NaN
# 13        NaN
# 16   2.856134
# 18   0.445686
# 34        NaN
# 39        NaN
# 44   2.560305
# 52   1.624630
# 58   4.024335
# 62   2.323069
# 63        NaN
# 76        NaN
# 77        NaN
# 78   3.408763
# 80   2.663033
# 83        NaN
# 85   1.445812
# 88   0.622228
# 90   2.248518
# 92   1.487597
# 96        NaN
# 97   3.149334
# 100       NaN
# 101       NaN
# 103       NaN
# 104       NaN
# 116  0.999140
# 118  1.651902
# 119  0.045331
# 121       NaN
# 124       NaN
# 125       NaN
# 129  4.679327
# 132  1.519675
# 138       NaN
# 140       NaN
# 144  1.175882
# 145  6.120381
# 146  0.660292
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 153       NaN
# 161       NaN
# 172       NaN
# 176       NaN
# 184       NaN
# 197  2.448299
# 198  2.104379
# 202       NaN
# 203  1.408122
# 206  1.382718
# 211  1.726096
# 215       NaN
# 216       NaN
# 218       NaN
# 222       NaN
# 224  2.229346
# 239       NaN   359
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-24c81871c453> in <module>()
#      27 for i in range(0, (2019-1990+1)*12+1):
#      28 #     plot(data[i], i)
# ---> 29     print(data[i], i)
#      30 # np.max([d['carspp'].max() for d in data])
#      31 # plot(data[11], 1990, 11)
#
# IndexError: list index out of range

# %%
# !ffmpeg -framerate 5 -i frames/frame_%4d.png -c:v h264 -r 30 vid.mp4
